# %%
#Condition Statements
mausam = input("aaj ka mossam kaisa hai? thanda/ garmi/ barish : ")
if(mausam == "thanda"):
    print("aaj to bhot thand ahi yarrr!!")
elif(mausam == "garmi"):
    print("aaja to bhot garmi hai kyo na barf ka gola ho jye")
elif(mausam == "barish"):
    print("chata dhyan se laekar jaiyo")
# Out:
# aaj to bhot thand ahi yarrr!!

# %%
#for i in range(start,stop,step)
for i in range(0,10,2):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
hungry = input("bhook lafi hai kya yes/no: ")
if(hungry == "yes"):
    print("samosa khaoge")
else:
    print("thoda orr wait karo")
# Out:
# thoda orr wait karo

# %%
n = int(input("Enter a number"))
print(n%5)
# Out:
# 3
