# %%
n = int(input("Enter a number"))
res = 0
while(n):
    res += n
    n -=1
print(res)
# Out:
# 55

# %%
n = int(input("Enter a number"))
flag = true
for i in range(2,int(n**0.5)):
     if(n%i == 0):
         flag = false
         break;
print("it is not")
# Out:
# It is not Prime N0:

# %%
#Create a function to check prime no:
def checkprime(n):
    flag = True
    for i in range(2,int(n**0.5)):
        if(n%i == 0):
            flag = False
            break;
    return flag;
n = int(input("Enter a number"))
print(checkprime(n))
# Out:
# False

# %%
#lambda functon
add = lambda x,y:x+y
print(add(10,20))
# Out:
# 30

# %%
def find_first_non_repeating_character(s):
    map={}
    for i in s:
        map[i] = map.get(i,0)+1
    for i in s:
        if map[i] ==1:
            return i
    return none
s = input()
print(find_first_non_repeating_character(s))
# Out:
# c

# %%
#reverse a string
s = "abcde"
a = 0
b = len(s)-1
